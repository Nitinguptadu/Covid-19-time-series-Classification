# %% [markdown]
# # Timeseries Forecasting

# %% [markdown]
# This notebook explains how to use `tsfresh` in time series foreacasting.
# Make sure you also read through the [documentation](https://tsfresh.readthedocs.io/en/latest/text/forecasting.html) to learn more on this feature.
#
# It is basically a copy of the other time series forecasting notebook, but this time using more than one
# stock.
# This is conceptionally not much different, but the pandas multi-index magic is a bit advanced :-)
#
# We will use the Google, Facebook and Alphabet stock.
# Please find all documentation in the other notebook.

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pylab as plt

from tsfresh import extract_features, select_features
from tsfresh.utilities.dataframe_functions import roll_time_series, make_forecasting_frame
from tsfresh.utilities.dataframe_functions import impute

try:
    import pandas_datareader.data as web
except ImportError:
    print("You need to install the pandas_datareader. Run pip install pandas_datareader.")

from sklearn.ensemble import AdaBoostRegressor

# %% [markdown]
# ## Reading the data

# %%
df_melted = pd.read_excel("train.xlsx")

# %%
df_melted.head()
# Out:
#    Unnamed: 0            Symbols  Time      High
# 0           0  1 sensor response     0  0.013786
# 1           1  1 sensor response     1  0.017507
# 2           2  1 sensor response     2  0.017326
# 3           3  1 sensor response     3  0.017236
# 4           4  1 sensor response     4  0.017610

# %% [markdown]
# ## Create training data sample

# %%
df_rolled = roll_time_series(df_melted, column_id="Symbols", column_sort="Time",
                             max_timeshift=999, min_timeshift=999)
# Out:
# Rolling: 100%|██████████| 30/30 [00:03<00:00,  8.15it/s]

# %%
df_rolled.tail()
# Out:
#        Unnamed: 0              Symbols  Time      High  \
# 76995       46995  9 sensor response 9   995  0.067651
# 76996       46996  9 sensor response 9   996  0.067713
# 76997       46997  9 sensor response 9   997  0.067775
# 76998       46998  9 sensor response 9   998  0.067836
# 76999       46999  9 sensor response 9   999  0.067897
#
#                                          id
# 76995  id=9 sensor response 9,timeshift=999
# 76996  id=9 sensor response 9,timeshift=999
# 76997  id=9 sensor response 9,timeshift=999
# 76998  id=9 sensor response 9,timeshift=999
# 76999  id=9 sensor response 9,timeshift=999

# %% [markdown]
# ## Extract Features

# %%
X = extract_features(df_rolled.drop("Symbols", axis=1), 
                     column_id="id", column_sort="Time", column_value="High", 
                     impute_function=impute, show_warnings=False)
# Out:
# Feature Extraction: 100%|██████████| 26/26 [00:19<00:00,  1.30it/s]

# %%
X.head()
# Out:
# variable                                 High__abs_energy  \
# id
# id=1 sensor response 1,timeshift=999            14.665560
# id=1 sensor response,timeshift=999             737.932646
# id=10  sensor response 10,timeshift=999         18.729054
# id=10  sensor response,timeshift=999             0.790253
# id=11  sensor response 11,timeshift=999         42.138557
#
# variable                                 High__absolute_sum_of_changes  \
# id
# id=1 sensor response 1,timeshift=999                          0.320984
# id=1 sensor response,timeshift=999                            2.107785
# id=10  sensor response 10,timeshift=999                       0.264712
# id=10  sensor response,timeshift=999                          0.118053
# id=11  sensor response 11,timeshift=999                       0.565351
#
# variable                                 High__agg_autocorrelation__f_agg_"mean"__maxlag_40  \
# id
# id=1 sensor response 1,timeshift=999                                              0.948025
# id=1 sensor response,timeshift=999                                                0.941218
# id=10  sensor response 10,timeshift=999                                           0.787110
# id=10  sensor response,timeshift=999                                              0.954875
# id=11  sensor response 11,timeshift=999                                           0.902953
#
# variable                                 High__agg_autocorrelation__f_agg_"median"__maxlag_40  \
# id
# id=1 sensor response 1,timeshift=999                                              0.948777
# id=1 sensor response,timeshift=999                                                0.947792
# id=10  sensor response 10,timeshift=999                                           0.789804
# id=10  sensor response,timeshift=999                                              0.957130
# id=11  sensor response 11,timeshift=999                                           0.897200
#
# variable                                 High__agg_autocorrelation__f_agg_"var"__maxlag_40  \
# id
# id=1 sensor response 1,timeshift=999                                              0.000919
# id=1 sensor response,timeshift=999                                                0.001742
# id=10  sensor response 10,timeshift=999                                           0.015492
# id=10  sensor response,timeshift=999                                              0.000706
# id=11  sensor response 11,timeshift=999                                           0.002869
#
# variable                                 High__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"max"  \
# id
# id=1 sensor response 1,timeshift=999                                             -0.048056
# id=1 sensor response,timeshift=999                                                0.615003
# id=10  sensor response 10,timeshift=999                                           0.108367
# id=10  sensor response,timeshift=999                                              0.011647
# id=11  sensor response 11,timeshift=999                                           0.088254
#
# variable                                 High__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"mean"  \
# id
# id=1 sensor response 1,timeshift=999                                             -0.048266
# id=1 sensor response,timeshift=999                                                0.594858
# id=10  sensor response 10,timeshift=999                                           0.105874
# id=10  sensor response,timeshift=999                                              0.011181
# id=11  sensor response 11,timeshift=999                                           0.084970
#
# variable                                 High__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"min"  \
# id
# id=1 sensor response 1,timeshift=999                                             -0.048442
# id=1 sensor response,timeshift=999                                                0.576394
# id=10  sensor response 10,timeshift=999                                           0.103238
# id=10  sensor response,timeshift=999                                              0.010705
# id=11  sensor response 11,timeshift=999                                           0.081467
#
# variable                                 High__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"var"  \
# id
# id=1 sensor response 1,timeshift=999                                         -3.066782e-07
# id=1 sensor response,timeshift=999                                            3.647206e-04
# id=10  sensor response 10,timeshift=999                                       8.501153e-06
# id=10  sensor response,timeshift=999                                          4.583489e-07
# id=11  sensor response 11,timeshift=999                                       1.392810e-05
#
# variable                                 High__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"max"  \
# id
# id=1 sensor response 1,timeshift=999                                             -0.041973
# id=1 sensor response,timeshift=999                                                0.693506
# id=10  sensor response 10,timeshift=999                                           0.117758
# id=10  sensor response,timeshift=999                                              0.013345
# id=11  sensor response 11,timeshift=999                                           0.106308
#
# variable                                 ...  \
# id                                       ...
# id=1 sensor response 1,timeshift=999     ...
# id=1 sensor response,timeshift=999       ...
# id=10  sensor response 10,timeshift=999  ...
# id=10  sensor response,timeshift=999     ...
# id=11  sensor response 11,timeshift=999  ...
#
# variable                                 High__symmetry_looking__r_0.9500000000000001  \
# id
# id=1 sensor response 1,timeshift=999                                              1.0
# id=1 sensor response,timeshift=999                                                1.0
# id=10  sensor response 10,timeshift=999                                           1.0
# id=10  sensor response,timeshift=999                                              1.0
# id=11  sensor response 11,timeshift=999                                           1.0
#
# variable                                 High__time_reversal_asymmetry_statistic__lag_1  \
# id
# id=1 sensor response 1,timeshift=999                                       3.191407e-05
# id=1 sensor response,timeshift=999                                         8.286899e-04
# id=10  sensor response 10,timeshift=999                                    7.323802e-06
# id=10  sensor response,timeshift=999                                       6.685702e-08
# id=11  sensor response 11,timeshift=999                                    3.826741e-05
#
# variable                                 High__time_reversal_asymmetry_statistic__lag_2  \
# id
# id=1 sensor response 1,timeshift=999                                       6.380381e-05
# id=1 sensor response,timeshift=999                                         1.660145e-03
# id=10  sensor response 10,timeshift=999                                    1.467303e-05
# id=10  sensor response,timeshift=999                                       1.315695e-07
# id=11  sensor response 11,timeshift=999                                    7.660806e-05
#
# variable                                 High__time_reversal_asymmetry_statistic__lag_3  \
# id
# id=1 sensor response 1,timeshift=999                                       9.566774e-05
# id=1 sensor response,timeshift=999                                         2.494069e-03
# id=10  sensor response 10,timeshift=999                                    2.203423e-05
# id=10  sensor response,timeshift=999                                       1.939840e-07
# id=11  sensor response 11,timeshift=999                                    1.150185e-04
#
# variable                                 High__value_count__value_-1  \
# id
# id=1 sensor response 1,timeshift=999                             0.0
# id=1 sensor response,timeshift=999                               0.0
# id=10  sensor response 10,timeshift=999                          0.0
# id=10  sensor response,timeshift=999                             0.0
# id=11  sensor response 11,timeshift=999                          0.0
#
# variable                                 High__value_count__value_0  \
# id
# id=1 sensor response 1,timeshift=999                           48.0
# id=1 sensor response,timeshift=999                              0.0
# id=10  sensor response 10,timeshift=999                         0.0
# id=10  sensor response,timeshift=999                            0.0
# id=11  sensor response 11,timeshift=999                         0.0
#
# variable                                 High__value_count__value_1  \
# id
# id=1 sensor response 1,timeshift=999                            0.0
# id=1 sensor response,timeshift=999                              0.0
# id=10  sensor response 10,timeshift=999                         0.0
# id=10  sensor response,timeshift=999                            0.0
# id=11  sensor response 11,timeshift=999                         0.0
#
# variable                                 High__variance  \
# id
# id=1 sensor response 1,timeshift=999           0.007273
# id=1 sensor response,timeshift=999             0.125729
# id=10  sensor response 10,timeshift=999        0.000956
# id=10  sensor response,timeshift=999           0.000101
# id=11  sensor response 11,timeshift=999        0.005031
#
# variable                                 High__variance_larger_than_standard_deviation  \
# id
# id=1 sensor response 1,timeshift=999                                               0.0
# id=1 sensor response,timeshift=999                                                 0.0
# id=10  sensor response 10,timeshift=999                                            0.0
# id=10  sensor response,timeshift=999                                               0.0
# id=11  sensor response 11,timeshift=999                                            0.0
#
# variable                                 High__variation_coefficient
# id
# id=1 sensor response 1,timeshift=999                        0.991945
# id=1 sensor response,timeshift=999                          0.453178
# id=10  sensor response 10,timeshift=999                     0.231872
# id=10  sensor response,timeshift=999                        0.383255
# id=11  sensor response 11,timeshift=999                     0.368201
#
# [5 rows x 763 columns]

# %%
X.to_excel("latest.xlsx")

# %%
pwd
# Out:
# '/home/nitin/Desktop/shanur/time series solution using tsfresh'

# %% [markdown]
# We make the data a bit easier to work with by giving them a multi-index instead ot the tuple index:
